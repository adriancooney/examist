# %% [markdown]
# This notebook will generate the module database from `mis.nuigalway.ie`.

# %%
import os, sys
import pandas

if os.getcwd().endswith("notebooks"):
    # %cd ..
    
from src.scraper import Scraper

modules = pandas.read_csv("./data/modules.csv")

modules
# Out:
#                                            name module_code
# 0                                   Accountancy          AY
# 1                                  Anaesthetics          AE
# 2                                       Anatomy          AN
# 3                          Anatomy / Physiology          AP
# 4                              Ancient Classics          AC
# 5    Applied Computing & Information Technology          CI
# 6                  Applied Mathematical Science          AS
# 7                           Applied Mathematics          AM
# 8                                   Archaeology          AR
# 9                           Arts Administration          AA
# 10                                    Astronomy          AT
# 11                                 Bacteriology          BR
# 12                                 Biochemistry          BI
# 13                     Biochemistry / Chemistry          BC
# 14                          Biological Sciences          BL
# ...
